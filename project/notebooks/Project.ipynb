# %% [markdown]
# **Project**
# **Portfolio Comparison and Optimization**

# %%
# loading data from yahoo finance
import yfinance as yf
import pandas as pd
import numpy as np

tickers= ["BLK", "JPM", "UBS"]
data = yf.download(tickers, start="2020-01-01", end="2023-12-31")
data.head()
# Out:
# C:\Users\dhair\AppData\Local\Temp\ipykernel_50868\1493497951.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start="2020-01-01", end="2023-12-31")
# [*********************100%***********************]  3 of 3 completed

# %%
data.head()
# Out:
# Price            Close                               High              \
# Ticker             BLK         JPM        UBS         BLK         JPM
# Date
# 2020-01-02  444.427826  120.154671  10.614063  445.318453  120.163195
# 2020-01-03  439.704010  118.569077  10.441544  442.437047  119.331881
# 2020-01-06  440.079437  118.474792  10.416899  440.751771  118.509083
# 2020-01-07  442.891083  116.460648  10.630494  445.161339  118.157671
# 2020-01-08  442.786346  117.369186  10.770152  445.440802  117.917720
#
# Price                         Low                               Open  \
# Ticker            UBS         BLK         JPM        UBS         BLK
# Date
# 2020-01-02  10.614063  440.882744  118.596210  10.408683  445.318453
# 2020-01-03  10.490835  437.913988  117.489155  10.392252  438.088634
# 2020-01-06  10.433329  435.285723  116.992040  10.334746  436.735195
# 2020-01-07  10.667463  439.101513  116.409225  10.567237  439.101513
# ...

# %%
data.describe()
# Out:
# Price         Close                                   High               \
# Ticker          BLK          JPM          UBS          BLK          JPM
# count   1006.000000  1006.000000  1006.000000  1006.000000  1006.000000
# mean     638.544974   121.735630    15.355350   645.399000   123.006861
# std      117.761759    22.030536     4.425896   117.645838    21.912604
# min      288.063690    67.735405     6.284643   312.082183    71.780846
# 25%      565.810745   106.198652    12.702973   573.415214   107.553776
# 50%      642.129639   126.417027    14.936596   648.912289   127.589759
# 75%      711.059723   139.063416    17.963201   717.461293   140.181177
# max      883.062439   163.672073    29.434223   884.580416   164.046893
#
# Price                        Low                                   Open  \
# Ticker          UBS          BLK          JPM          UBS          BLK
# count   1006.000000  1006.000000  1006.000000  1006.000000  1006.000000
# ...

# %%
data.to_csv(r""C:\Users\dhair\bootcamp_dhairya_gouchwal\project\data\raw"
